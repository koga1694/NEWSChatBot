# %%
#참고 : https://bigdata-doctrine.tistory.com/34

# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
from fake_useragent import UserAgent
import datetime
from urllib import parse
from tqdm.notebook import tqdm

URL = "https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1={}&sid2={}&date={}&page={}"
SID = [
    {'sid1': '100', 'sid2': '264', 'name1': '정치', 'name2': '대통령실'}, 
    {'sid1': '100', 'sid2': '265', 'name1': '정치', 'name2': '국회/정당'}, 
    {'sid1': '100', 'sid2': '268', 'name1': '정치', 'name2': '북한'}, 
    {'sid1': '100', 'sid2': '266', 'name1': '정치', 'name2': '행정'}, 
    {'sid1': '100', 'sid2': '267', 'name1': '정치', 'name2': '국방/외교'}, 
    {'sid1': '100', 'sid2': '269', 'name1': '정치', 'name2': '정치일반'}, 
    {'sid1': '101', 'sid2': '259', 'name1': '경제', 'name2': '금융'}, 
    {'sid1': '101', 'sid2': '258', 'name1': '경제', 'name2': '증권'}, 
    {'sid1': '101', 'sid2': '261', 'name1': '경제', 'name2': '산업/재계'}, 
    {'sid1': '101', 'sid2': '771', 'name1': '경제', 'name2': '중기/벤처'}, 
    {'sid1': '101', 'sid2': '260', 'name1': '경제', 'name2': '부동산'}, 
    {'sid1': '101', 'sid2': '262', 'name1': '경제', 'name2': '글로벌 경제'}, 
    {'sid1': '101', 'sid2': '310', 'name1': '경제', 'name2': '생활경제'}, 
    {'sid1': '101', 'sid2': '263', 'name1': '경제', 'name2': '경제 일반'}, 
    {'sid1': '102', 'sid2': '249', 'name1': '사회', 'name2': '사건사고'}, 
    {'sid1': '102', 'sid2': '250', 'name1': '사회', 'name2': '교육'}, 
    {'sid1': '102', 'sid2': '251', 'name1': '사회', 'name2': '노동'}, 
    {'sid1': '102', 'sid2': '254', 'name1': '사회', 'name2': '언론'}, 
    {'sid1': '102', 'sid2': '252', 'name1': '사회', 'name2': '환경'}, 
    {'sid1': '102', 'sid2': '59b', 'name1': '사회', 'name2': '인권/복지'}, 
    {'sid1': '102', 'sid2': '255', 'name1': '사회', 'name2': '식품/의료'}, 
    {'sid1': '102', 'sid2': '256', 'name1': '사회', 'name2': '지역'}, 
    {'sid1': '102', 'sid2': '276', 'name1': '사회', 'name2': '인물'}, 
    {'sid1': '102', 'sid2': '257', 'name1': '사회', 'name2': '사회 일반'}, 
    {'sid1': '103', 'sid2': '241', 'name1': '생활문화', 'name2': '건강정보'}, 
    {'sid1': '103', 'sid2': '239', 'name1': '생활문화', 'name2': '자동차/시승기'}, 
    {'sid1': '103', 'sid2': '240', 'name1': '생활문화', 'name2': '도로/교통'}, 
    {'sid1': '103', 'sid2': '237', 'name1': '생활문화', 'name2': '여행/레저'}, 
    {'sid1': '103', 'sid2': '238', 'name1': '생활문화', 'name2': '음식/맛집'}, 
    {'sid1': '103', 'sid2': '376', 'name1': '생활문화', 'name2': '패션/뷰티'}, 
    {'sid1': '103', 'sid2': '242', 'name1': '생활문화', 'name2': '공연/전시'}, 
    {'sid1': '103', 'sid2': '243', 'name1': '생활문화', 'name2': '책'}, 
    {'sid1': '103', 'sid2': '244', 'name1': '생활문화', 'name2': '종교'}, 
    {'sid1': '103', 'sid2': '248', 'name1': '생활문화', 'name2': '날씨'}, 
    {'sid1': '103', 'sid2': '245', 'name1': '생활문화', 'name2': '생활문화 일반'}, 
    {'sid1': '104', 'sid2': '231', 'name1': '세계', 'name2': '아시아/호주'}, 
    {'sid1': '104', 'sid2': '232', 'name1': '세계', 'name2': '미국/중남미'}, 
    {'sid1': '104', 'sid2': '233', 'name1': '세계', 'name2': '유럽'}, 
    {'sid1': '104', 'sid2': '234', 'name1': '세계', 'name2': '중동/아프리카'}, 
    {'sid1': '104', 'sid2': '322', 'name1': '세계', 'name2': '세계 일반'}, 
    {'sid1': '105', 'sid2': '731', 'name1': 'IT/과학', 'name2': '모바일'}, 
    {'sid1': '105', 'sid2': '226', 'name1': 'IT/과학', 'name2': '인터넷/SNS'}, 
    {'sid1': '105', 'sid2': '227', 'name1': 'IT/과학', 'name2': '통신/뉴미디어'}, 
    {'sid1': '105', 'sid2': '230', 'name1': 'IT/과학', 'name2': 'IT 일반'}, 
    {'sid1': '105', 'sid2': '732', 'name1': 'IT/과학', 'name2': '보안/해킹'}, 
    {'sid1': '105', 'sid2': '283', 'name1': 'IT/과학', 'name2': '컴퓨터'}, 
    {'sid1': '105', 'sid2': '229', 'name1': 'IT/과학', 'name2': '게임/리뷰'}, 
    {'sid1': '105', 'sid2': '228', 'name1': 'IT/과학', 'name2': '과학 일반'},
]
newlines = {
    "br", "div", "p"
}
DAY = datetime.datetime.now().replace(hour=0, minute=0, second=0, microsecond=0) - datetime.timedelta(days=1)
DAY = DAY.strftime('%Y%m%d')
UA = UserAgent().random

def Crawling(SID, URL, DAY, UA):
    url_list = []
    for sid in SID:
        url = URL.format(sid['sid1'], sid['sid2'], DAY, '10')
        url_list.append(url)
    return url
        
def art_crawl(url):
    """
    sid와 링크 인덱스를 넣으면 기사제목, 날짜, 본문을 크롤링하여 딕셔너리를 출력하는 함수 
    
    Args: 
        urls(dict): 각 분야별로 100페이지까지 링크를 수집한 딕셔너리 (key: 분야(sid), value: 링크)
        sid(int): 분야 [100: 정치, 101: 경제, 102: 사회, 103: 생활/문화, 104: 세계, 105: IT/과학]
        index(int): 링크의 인덱스
    
    Returns:
        dict: 기사제목, 날짜, 본문이 크롤링된 딕셔너리
    
    """
    # art_dic = {}
    
    ## 1.
    # title_selector = "#title_area > span"
    date_selector = "#ct > div.media_end_head.go_trans > div.media_end_head_info.nv_notrans"\
    "> div.media_end_head_info_datestamp > div:nth-child(1) > span"
    main_selector = "#dic_area"
    
    # url = urls[sid][index]
    # url = urls['url']
    html = requests.get(url, headers={"User-Agent":  "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/116.0"}, verify=False)
    soup = BeautifulSoup(html.text, "lxml")
    
    ## 2.
    # 제목 수집
    # title = soup.select(title_selector)
    # title_lst = [t.text for t in title]
    # title_str = "".join(title_lst)
    
    # 날짜 수집
    date = soup.select(date_selector)
    date_lst = [d.text for d in date]
    date_str = "".join(date_lst)
    
    # 본문 수집
    main = soup.select(main_selector)
    main_lst = []
    for m in main:
        m_text = m.text
        m_text = m_text.strip()
        main_lst.append(m_text)
    main_str = "".join(main_lst)
    
    ## 3.
    # art_dic["title"] = title_str
    # art_dic["date"] = date_str
    # art_dic["main"] = main_str
    
    return date_str, main_str

""" 뉴스 페이지 목록 조회 """
def news_list_item(soup, name1, name2, mains):
    dataset = []
    items = soup.select("#main_content > div.list_body.newsflash_body > ul > li > dl > dt[class!='photo'] > a")
    for item in tqdm(items):
        url, title = item["href"], item.text.strip()     
        date, main = art_crawl(url)
        if item not in mains:
            if 0 < len(title):
                dataset.append({"대분류": name1, "소분류": name2, "url": url, "title": title, "date": date, "main": main})
            mains.append(item)
        else:
            break
    return dataset

from time import sleep

""" 뉴스 페이지 목록 조회 """
def news_list_page(date):
    keys = set()
    urls = []
    names = []
    dataset = []
    # 뉴스테마별 딕셔너리
    urlset = dict()
    for sid in SID:
        urlset[sid["sid1"], sid["sid2"]] = []
        # max page 99
        for page in range(1,99):
            sid1, sid2, page = sid["sid1"], sid["sid2"], page
            key = f"{sid1}.{sid2}.{page}"
            if key not in keys:
                keys.add(key)
                urlset[sid["sid1"], sid["sid2"]].append(URL.format(sid1, sid2, date, page))
                names.append([sid['name1'], sid['name2']])
    index = 0
    for tm_url in list(urlset.values()):
        # 각 세부테마별 중복 url 존재시 멈춤 (ex. 마지막 페이지 다음 페이지에서는 url이 겹치므로 정지)
        url_main = []
        for url in tm_url:     
            print(url)
            html = requests.get(url, headers={"User-Agent":  "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/116.0"}, verify=False)
            soup = BeautifulSoup(html.text, "lxml")
            print(f"========={names[index][0], names[index][1]}=========")
            name1, name2 = names[index][0], names[index][1]
            items = news_list_item(soup, name1, name2, url_main)
            dataset.extend(items)
            # Max retries exceeded with URL in requests 방지
            sleep(0.5)
            index = index + 1
        print("=============================================수집완료======================================================")
    return dataset

# %%
import urllib3

urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

dum = news_list_page('20230813')
# Out:
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=1
# =========('정치', '대통령실')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=2
# =========('정치', '대통령실')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=3
# =========('정치', '대통령실')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=4
# =========('정치', '대통령실')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=5
# =========('정치', '대통령실')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=6
# =========('정치', '대통령실')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=7
# =========('정치', '대통령실')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=8
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=9
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=10
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=11
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=12
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=13
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=14
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=15
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=16
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=17
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=18
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=19
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=20
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=21
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=22
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=23
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=24
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=25
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=26
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=27
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=28
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=29
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=30
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=31
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=32
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=33
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=34
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=35
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=36
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=37
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=38
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=39
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=40
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=41
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=42
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=43
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=44
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=45
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=46
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=47
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=48
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=49
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=50
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=51
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=52
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=53
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=54
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=55
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=56
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=57
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=58
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=59
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=60
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=61
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=62
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=63
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=64
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=65
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=66
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=67
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=68
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=69
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=70
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=71
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=72
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=73
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=74
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=75
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=76
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=77
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=78
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=79
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=80
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=81
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=82
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=83
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=84
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=85
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=86
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=87
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=88
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=89
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=90
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=91
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=92
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=93
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=94
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=95
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=96
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2=264&date=20230813&page=97
# =========('정치', '대통령실')=========
#   0%|          | 0/14 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=100&sid2
[00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=276&date=20230813&page=83
# =========('사회', '인물')=========
#   0%|          | 0/13 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=276&date=20230813&page=84
# =========('사회', '인물')=========
#   0%|          | 0/13 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=276&date=20230813&page=85
# =========('사회', '인물')=========
#   0%|          | 0/13 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=276&date=20230813&page=86
# =========('사회', '인물')=========
#   0%|          | 0/13 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=276&date=20230813&page=87
# =========('사회', '인물')=========
#   0%|          | 0/13 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=276&date=20230813&page=88
# =========('사회', '인물')=========
#   0%|          | 0/13 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=276&date=20230813&page=89
# =========('사회', '인물')=========
#   0%|          | 0/13 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=276&date=20230813&page=90
# =========('사회', '인물')=========
#   0%|          | 0/13 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=276&date=20230813&page=91
# =========('사회', '인물')=========
#   0%|          | 0/13 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=276&date=20230813&page=92
# =========('사회', '인물')=========
#   0%|          | 0/13 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=276&date=20230813&page=93
# =========('사회', '인물')=========
#   0%|          | 0/13 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=276&date=20230813&page=94
# =========('사회', '인물')=========
#   0%|          | 0/13 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=276&date=20230813&page=95
# =========('사회', '인물')=========
#   0%|          | 0/13 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=276&date=20230813&page=96
# =========('사회', '인물')=========
#   0%|          | 0/13 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=276&date=20230813&page=97
# =========('사회', '인물')=========
#   0%|          | 0/13 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=276&date=20230813&page=98
# =========('사회', '인물')=========
#   0%|          | 0/13 [00:00<?, ?it/s]
# =============================================수집완료======================================================
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=1
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=2
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=3
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=4
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=5
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=6
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=7
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=8
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=9
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=10
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=11
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=12
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=13
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=14
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=15
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=16
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=17
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=18
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=19
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=20
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=21
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=22
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=23
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=24
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=25
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=26
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=27
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=28
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=29
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=30
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=31
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=32
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=33
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=34
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=35
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=36
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=37
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=38
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=39
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=40
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=41
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=42
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=43
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=44
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=45
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=46
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=47
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=48
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=49
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=50
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=51
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=52
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=53
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=54
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=55
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=56
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=57
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=58
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=59
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=60
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=61
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=62
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=63
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=64
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=65
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=66
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=67
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=68
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=69
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=70
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]
# https://news.naver.com/main/list.nhn?mode=LS2D&mid=shm&sid1=102&sid2=257&date=20230813&page=71
# =========('사회', '사회 일반')=========
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
import pandas as pd

art_df = pd.DataFrame(dum)

# %%
art_df

# %%
# 출력 옵션 설정
# pd.set_option("display.max_rows", None)  # 모든 행 표시
pd.set_option("display.max_columns", None)  # 모든 열 표시
pd.set_option("display.width", None)  # 줄 바꿈 없이 전체 내용 표시

# %%
# 텍스트 전처리
def text_preprocessing(text):
    text = text.replace('\n', '')
    text = text.replace('   ', ' ')
    text = text.replace('\\', '')
    return text

# %%
art_df['main'] = art_df['main'].apply(text_preprocessing)

# %%
from datetime import datetime

def to_dt_time(date):
    if date != '':
        date = datetime.strptime(date[:10], '%Y.%m.%d')
        date = date.strftime('%Y-%m-%d')
        return date
    else:
        return date

# %%
# 날짜
now = datetime.now()
now = now.date().strftime('%Y-%m-%d')

art_df['ymd'] = art_df['date'].apply(to_dt_time)

# %%
art_df

# %%
art_df[['대분류', '소분류','url']].groupby(['대분류', '소분류']).count()

# %%
art_df.to_csv("article_df.csv")
